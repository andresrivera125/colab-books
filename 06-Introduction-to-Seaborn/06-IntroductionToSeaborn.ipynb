# %% [markdown]
# <a href="https://colab.research.google.com/github/andresrivera125/colab-books/blob/main/06-Introduction-to-Seaborn/06-IntroductionToSeaborn.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Chapter 01 - Introduction to Seaborn
#
# How to import the library
#
# ```
# import seaborn as sns
# import matplotlib.pyplot as plt
# ```
#
# Let's see some examples.

# %%
import seaborn as sns
import matplotlib.pyplot as plt

weight = [62, 64, 69, 75, 66,
      68, 65, 71, 76, 73]

height = [120, 136, 148, 175, 137, 
      165, 154, 172, 200, 187]

sns.scatterplot(x=height, y=weight)
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

FEMALE = "Female"
MALE = "Male"
gender = [FEMALE,
          FEMALE,
          FEMALE,
          FEMALE,
          MALE,
          MALE,
          MALE,
          MALE,
          MALE,
          MALE,
          MALE,
          MALE
          ]

sns.countplot(x=gender)

# %% [markdown]
# ## Using pandas with Seaborn

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv("masculinity.csv")

# Take a look of the structure
# We will see three columns:
print(df.head())

# %% [markdown]
# ![Course06SeabornChapter01-Image001.png](data:image/png;base64,...)

# %%
# We will use here just the column "how_masculine" from df
sns.countplot(x="how_masculine",
              data=df
              )

plt.show()

# %% [markdown]
# You will see the following figure.
#
# ![Course06SeabornChapter01-Image002.png](data:image/png;base64,...)

# %% [markdown]
# ## Adding a third variable with hue

# %%
import pandas as pd
import seaborn as sns

tips = sns.load_dataset("tips")
print(tips.head())

sns.scatterplot(x="total_bill",
                y="tip",
                data=tips
                )

plt.show()

# %% [markdown]
# ![Course06SeabornChapter01-Image003.png](data:image/png;base64,...)

# %% [markdown]
# You can set the "hue" parameter equal to the DataFrame column name "smoker" and then Seaborn will automatically color each point by whether they are a smoker.  Plus, it will add a legend to the plot automatically!
#
# ![Course06SeabornChapter01-Image004.png](data:image/png;base64,...)

# %%
import pandas as pd
import matplotlib.pyplt as plt
import seaborn as sns

tips = sns.load_dataset("tips")
print(tips.head())

sns.scatterplot(x="total_bill",
                y="tip",
                data=tips,
                hue="smoker"
                )

plt.show()

# %% [markdown]
# ## Setting hue order
#
# If you don't want to use Pandas, you can set it equal to a list of values instead of a column name.
#
# Hue also allows you to assert more control over the ordering and coloring of each value.  The "hue_order" parameter takes in a list of values and will set the order of the values in the plot accordingly.

# %%
import matplotlib.pyplt as plt
import seaborn as sns

tips = sns.load_dataset("tips")
print(tips.head())

sns.scatterplot(x="total_bill",
                y="tip",
                data=tips,
                hue="smoker",
                hue_order=["Yes", "No"]
                )

plt.show()

# %% [markdown]
# ![Course06SeabornChapter01-Image005.png](data:image/png;base64,...)

# %% [markdown]
# ## Specifying hue colors
#
# Here, we will create a dictionary called "hue_colors" that maps the value "Yes" to the color black and the value "No" to the color red.

# %%
import matplotlib.pyplt as plt
import seaborn as sns

hue_colors = {"Yes": "black".
              "No": "red"
              }

sns.scatterplot(x="total_bill",
                y="tip",
                data=tips,
                hue="smoker",
                palette=hue_colors
                )

plt.show()

# %% [markdown]
# ![Course06SeabornChapter01-Image006.png](data:image/png;base64,...)

# %% [markdown]
# ## A palette of colors
#
# ![Course06SeabornChapter01-Image007.png](data:image/png;base64,...)

# %% [markdown]
# ## An example using Hex codes

# %%
hue_colors = {"Yes": "#808080",
              "No": "#00FF00"
              }

# %% [markdown]
# ## Using hue with count plots

# %%
import matplotlib.pyplt as plt
import seaborn as sns

sns.countplot(x="smoker"
              data="tips",
              hue="sex"
)

plt.show()

# %% [markdown]
# ![Course06SeabornChapter01-Image008.png](data:image/png;base64,...)

# %% [markdown]
# # Chapter 02 - Visualizing Two Quantitative Variables

# %% [markdown]
# ## Introduction to relational plots and subplots
#
# relplot() means relational plot. It works to scatter or lineal plots.

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.scatterplot(x="total_bil"
                y="bill",
                data=tips
)

plt.show()

## And now let's compare with relplot
# kind key-word specify what kind of relational
# plot to use: scatter or line plot

sns.relplot(
    x="total_bill",
    y="tip",
    data=tips,
    kind="scatter"
)

plt.show()

# If we add the key-word col, we will get two figure
# one for smokers and the another to non-smokers

sns.relplot(
    x="total_bill",
    y="tip",
    data=tips,
    kind="scatter",
    col="smoker"
)

plt.show()

# %% [markdown]
# ![relplot-image001.png](data:image/png;base64,...)

# %%
# if we want to arrange these vertically in rows instead,
# we can use the "row" parameter instead of "col"

sns.relplot(
    x="total_bill",
    y="tip",
    data=tips,
    kind="scatter",
    row="smoker"
)

plt.show()

# %% [markdown]
# ![relplot-image002.png](data:image/png;base64,...)

# %%
# You can use both "col" and "row"
# at the same time

sns.relplot(
    x="total_bill",
    y="tip",
    data=tips,
    kind="scatter",
    col="smoker",
    row="time"
)

plt.show()

# %% [markdown]
# ![relplot-image003.png](data:image/png;base64,...)

# %%
# You can specify how many cols you want per row

sns.relplot(
    x="total_bill",
    y="tip",
    data=tips,
    kind="scatter",
    col="day",
    col_wrap=2
)

plt.show()

# %% [markdown]
# ![relplot-image004.png](data:image/png;base64,...)

# %%
# We can also change the order of the subplots

sns.relplot(
    x="total_bill",
    y="tip",
    data=tips,
    kind="scatter",
    col="day",
    col_wrap=2,
    col_order=[
               "Thur",
               "Fri",
               "Sat",
               "Sun"
    ]
)

plt.show()

# %% [markdown]
# ![relplot-image005.png](data:image/png;base64,...)

# %%
# Another example using row_order

# Adjust further to add subplots based on family support
sns.relplot(x="G1", y="G3", 
            data=student_data,
            kind="scatter", 
            col="schoolsup",
            col_order=["yes", "no"],
            row="famsup",
            row_order=["yes", "no"],)

# Show plot
plt.show()

# %% [markdown]
# ## Customizing scatter plots
#
# ![relplot-image006.png](data:image/png;base64,...)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.relplot(
    x="total_bill", 
    y="tip", 
    data=tips,
    kind="scatter", 
    size="size",
    hue="size",
    style="smoker"
)

# Show plot
plt.show()

# %% [markdown]
# ![relplot-image008.png](data:image/png;base64,...)

# %% [markdown]
# ![relplot-image007.png](data:image/png;base64,...)

# %% [markdown]
# ### Changing point transparency

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.relplot(
    x="total_bill", 
    y="tip", 
    data=tips,
    kind="scatter", 
    alpha=0.4
)

# Show plot
plt.show()

# %% [markdown]
# ![relplot-image009.png](data:image/png;base64,...)

# %% [markdown]
# ## Line plots
#
# ![relplot-image010.png](data:image/png;base64,...)

# %% [markdown]
# ![relplot-image011.png](data:image/png;base64,...)

# %% [markdown]
# ![relplot-image012.png](data:image/png;base64,...)

# %% [markdown]
# ![relplot-image013.png](data:image/png;base64,...)

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.relplot(
    x="hour",
    y="NO_2_mean",
    kind="line",
    style="location",
    hue="location",
    markers=True,
    dashes=False
)

# %% [markdown]
# ## Confidence Interval (CI)
#
# ![relplot-image014.png](data:image/png;base64,...)

# %% [markdown]
# ![relplot-image015.png](data:image/png;base64,...)

# %% [markdown]
# ![relplot-image018.png](data:image/png;base64,...)

# %% [markdown]
# ![relplot-image016.png](data:image/png;base64,...)

# %% [markdown]
# ![relplot-image017.png](data:image/png;base64,...)

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# ci could be "sd", None, or ommitted

sns.relplot(
    x="hour",
    y="NO_2",
    data=air_df,
    kind="line",
    ci=None
)

# %% [markdown]
# # Chapter 03 - Count plots and bar plots
